# %%
import numpy as np
import pandas as pd

# %%
ngrams = pd.read_csv("imslp-interval-2gram-20110401.csv", sep='\t', header=None)
ngrams[ngrams[1] > 2009]
# Out:
#              0     1   2
# 264     -1 -10  2010  20
# 624     -1 -11  2010   7
# 956     -1 -12  2010  10
# 1199    -1 -13  2010   3
# 1501    -1 -14  2010   6
# ...        ...   ...  ..
# 953965    9 12  2010  13
# 955581     9 1  2010   4
# 957111     9 2  2010   7
# 957868     9 3  2010   8
# 959093     9 7  2010   4
#
# [919 rows x 3 columns]
